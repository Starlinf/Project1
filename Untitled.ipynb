# %%
# Dependencies
import pandas as pd

# %%
# Store filepath in a variable
file_one = "Affinity-State-Daily.csv"

# %%
# Read our Data file with the pandas library
file_one_df = pd.read_csv(file_one)

# %%
# Show just the header
file_one_df.head()
# Out:
#    year  month  day  statefips  spend_acf  spend_aer  spend_all  \
# 0  2020      1   24          1  -0.000859    0.03580    0.00634
# 1  2020      1   24          2   0.007130    0.04920   -0.02640
# 2  2020      1   24          4  -0.009150    0.04490   -0.01260
# 3  2020      1   24          5   0.024400   -0.05270   -0.00707
# 4  2020      1   24          6   0.004130   -0.00378    0.00813
#
#   spend_all_inchigh spend_all_inclow  spend_all_incmiddle  spend_apg  \
# 0            0.0219         0.000657              0.00687   -0.02130
# 1           -0.0106                .             -0.06990    0.15900
# 2          -0.00749         -0.00918             -0.01670   -0.01190
# 3            0.0048         -0.00166             -0.01080    0.00842
# 4           0.00719           0.0124              0.00905   -0.01150
#
#    spend_grf  spend_hcs  spend_tws
# 0    0.00718    0.05700   -0.01760
# 1   -0.03270   -0.15400   -0.07230
# 2   -0.01160    0.02070   -0.04610
# 3   -0.02800    0.00586    0.00444
# 4    0.01610    0.02030   -0.00473

# %%
# Store filepath in a variable
file_two = "UI_Claims-State-Weekly.csv"

# %%
# Read our Data file with the pandas library
file_two_df = pd.read_csv(file_two)

# %%
# Show just the header
file_two_df.head()
# Out:
#    year  month  day_endofweek  statefips  initial_claims  initial_claims_rate  \
# 0  2020      3             14          1            1819               0.0811
# 1  2020      3              7          1            1663               0.0742
# 2  2020      1             11          1            3629               0.1620
# 3  2020      1              4          1            4578               0.2040
# 4  2020      4             25          1           74966               3.3400
#
#    total_claims  total_claims_rate
# 0         14889              0.664
# 1         15320              0.683
# 2         24772              1.110
# 3         23101              1.030
# 4        248821             11.100

# %%
# Merge two dataframes using an inner join
merge_df_1 = pd.merge(file_one_df, file_two_df , on="statefips")
merge_df_1
# Out:
#         year_x  month_x  day  statefips  spend_acf  spend_aer  spend_all  \
# 0         2020        1   24          1  -0.000859     0.0358    0.00634
# 1         2020        1   24          1  -0.000859     0.0358    0.00634
# 2         2020        1   24          1  -0.000859     0.0358    0.00634
# 3         2020        1   24          1  -0.000859     0.0358    0.00634
# 4         2020        1   24          1  -0.000859     0.0358    0.00634
# ...        ...      ...  ...        ...        ...        ...        ...
# 178699    2020        6   17         56  -0.277000    -0.3790   -0.04870
# 178700    2020        6   17         56  -0.277000    -0.3790   -0.04870
# 178701    2020        6   17         56  -0.277000    -0.3790   -0.04870
# 178702    2020        6   17         56  -0.277000    -0.3790   -0.04870
# 178703    2020        6   17         56  -0.277000    -0.3790   -0.04870
#
#        spend_all_inchigh spend_all_inclow  spend_all_incmiddle  ...  \
# 0                 0.0219         0.000657              0.00687  ...
# 1                 0.0219         0.000657              0.00687  ...
# 2                 0.0219         0.000657              0.00687  ...
# 3                 0.0219         0.000657              0.00687  ...
# 4                 0.0219         0.000657              0.00687  ...
# ...                  ...              ...                  ...  ...
# 178699           -0.0185          0.00874             -0.05840  ...
# 178700           -0.0185          0.00874             -0.05840  ...
# 178701           -0.0185          0.00874             -0.05840  ...
# 178702           -0.0185          0.00874             -0.05840  ...
# 178703           -0.0185          0.00874             -0.05840  ...
#
#         spend_grf  spend_hcs  spend_tws  year_y  month_y  day_endofweek  \
# 0         0.00718   0.057000    -0.0176    2020        3             14
# 1         0.00718   0.057000    -0.0176    2020        3              7
# 2         0.00718   0.057000    -0.0176    2020        1             11
# 3         0.00718   0.057000    -0.0176    2020        1              4
# 4         0.00718   0.057000    -0.0176    2020        4             25
# ...           ...        ...        ...     ...      ...            ...
# 178699    0.01610   0.000431    -0.4220    2020        2             29
# 178700    0.01610   0.000431    -0.4220    2020        4             18
# 178701    0.01610   0.000431    -0.4220    2020        2              8
# 178702    0.01610   0.000431    -0.4220    2020        5             16
# 178703    0.01610   0.000431    -0.4220    2020        6              6
#
#         initial_claims  initial_claims_rate  total_claims  total_claims_rate
# 0                 1819               0.0811         14889              0.664
# 1                 1663               0.0742         15320              0.683
# 2                 3629               0.1620         24772              1.110
# 3                 4578               0.2040         23101              1.030
# 4                74966               3.3400        248821             11.100
# ...                ...                  ...           ...                ...
# 178699             471               0.1610          4014              1.370
# 178700            4381               1.5000         18683              6.390
# 178701             589               0.2020          4096              1.400
# 178702            2303               0.7880         19638              6.720
# 178703            2013               0.6890         17565              6.010
#
# [178704 rows x 21 columns]
